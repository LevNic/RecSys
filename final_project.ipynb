# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

# Модель второго уровня
from lightgbm import LGBMClassifier

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# Написанные нами функции
from src.metrics import precision_at_k, recall_at_k
from src.utils import prefilter_items
from src.recommenders import MainRecommender

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Загружаем данные

# %%
data = pd.read_csv('../data/retail_train.csv')
item_features = pd.read_csv('../data/product.csv')
user_features = pd.read_csv('../data/hh_demographic.csv')

# %%
data.head()
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
# 2     2375  26984851472    1  1036325         1         0.99       364
# 3     2375  26984851472    1  1082185         1         1.21       364
# 4     2375  26984851472    1  8160430         1         1.50       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0        -0.60        1631        1          0.0                0.0
# 1         0.00        1631        1          0.0                0.0
# 2        -0.30        1631        1          0.0                0.0
# 3         0.00        1631        1          0.0                0.0
# 4        -0.39        1631        1          0.0                0.0

# %%
item_features.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
user_features.head()
# Out:
#   AGE_DESC MARITAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC      HH_COMP_DESC  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
#
#   HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  household_key
# 0                   2      None/Unknown              1
# 1                   2      None/Unknown              7
# 2                   3                 1              8
# 3                   4                 2             13
# 4                   1      None/Unknown             16

# %%
item_features.columns = [col.lower() for col in item_features.columns]
item_features.rename(columns={'product_id': 'item_id'}, inplace=True)

# %%
item_features.head()
# Out:
#    item_id  manufacturer    department     brand            commodity_desc  \
# 0    25671             2       GROCERY  National                  FRZN ICE
# 1    26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2    26093            69        PASTRY   Private                     BREAD
# 3    26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4    26355            69       GROCERY   Private             COOKIES/CONES
#
#             sub_commodity_desc curr_size_of_product
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
user_features.columns = [col.lower() for col in user_features.columns]
user_features.rename(columns={'household_key': 'user_id'}, inplace=True)
user_features.head()
# Out:
#   age_desc marital_status_code income_desc homeowner_desc      hh_comp_desc  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
#
#   household_size_desc kid_category_desc  user_id
# 0                   2      None/Unknown        1
# 1                   2      None/Unknown        7
# 2                   3                 1        8
# 3                   4                 2       13
# 4                   1      None/Unknown       16

# %% [markdown]
# Разбиваем датасет на три части - давние покупки, 6 недель, 3 - недели.

# %%
val_lvl_1_size_weeks = 6
val_lvl_2_size_weeks = 3

data_train_lvl_1 = data[data['week_no'] < data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)]
data_val_lvl_1 = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

data_train_lvl_2 = data_val_lvl_1.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться
data_val_lvl_2 = data[data['week_no'] >= data['week_no'].max() - val_lvl_2_size_weeks]

data_train_lvl_1.head()
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
# 2     2375  26984851472    1  1036325         1         0.99       364
# 3     2375  26984851472    1  1082185         1         1.21       364
# 4     2375  26984851472    1  8160430         1         1.50       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0        -0.60        1631        1          0.0                0.0
# 1         0.00        1631        1          0.0                0.0
# 2        -0.30        1631        1          0.0                0.0
# 3         0.00        1631        1          0.0                0.0
# 4        -0.39        1631        1          0.0                0.0

# %% [markdown]
# Производим предварительную фильтрацию, выбрав только 5000 уникальных товаров

# %%
n_items_before = data_train_lvl_1['item_id'].nunique()

data_train_lvl_1 = prefilter_items(data_train_lvl_1)

n_items_after = data_train_lvl_1['item_id'].nunique()
print(f'Decreased # items from {n_items_before} to {n_items_after}')
# Out:
# Decreased # items from 83685 to 5001

# %% [markdown]
# Создаем рекомендательную модель 1 уровня

# %%
recommender = MainRecommender(data_train_lvl_1)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5001.0), HTML(value='')))

# %% [markdown]
# Сгруппируем данные для второй части данных

# %%
result_lvl_1 = data_val_lvl_1.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_1.columns=['user_id', 'actual']
result_lvl_1['actual'] = list(result_lvl_1['actual'])
result_lvl_1.head()
# Out:
#    user_id                                             actual
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [1024306, 1102949, 6548453, 835394, 940804, 96...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...

# %% [markdown]
# Для модели первого уровня выберем модель, рекомендующую 50 кандидатов среди тех товаров, которые юзер уже купил. Найдем кандидатов для второго уровня модели

# %%
users_lvl_2 = pd.DataFrame(data_train_lvl_2['user_id'].unique())
users_lvl_2.columns = ['user_id']

train_users = data_train_lvl_1['user_id'].unique()
users_lvl_2 = users_lvl_2[users_lvl_2['user_id'].isin(train_users)]

users_lvl_2['candidates'] = users_lvl_2['user_id'].apply(lambda x: recommender.get_own_recommendations(x, N=50))
users_lvl_2.head()
# Out:
#    user_id                                         candidates
# 0     2070  [1105426, 1097350, 879194, 948640, 928263, 944...
# 1     2021  [950935, 1119454, 835578, 863762, 1019142, 102...
# 2     1753  [967041, 963686, 948640, 1057168, 942475, 9553...
# 3     2120  [5707857, 1029743, 1106523, 5569230, 916122, 8...
# 4     1346  [1135983, 5569309, 1129982, 5574377, 5569993, ...

# %% [markdown]
# Тренировочный набор данных для второй модели

# %%
data_train_lvl_2.head()
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2104867     2070  40618492260  594  1019940         1         1.00       311
# 2107468     2021  40618753059  594   840361         1         0.99       443
# 2107469     2021  40618753059  594   856060         1         1.77       443
# 2107470     2021  40618753059  594   869344         1         1.67       443
# 2107471     2021  40618753059  594   896862         2         5.00       443
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2104867        -0.29          40       86          0.0                0.0
# 2107468         0.00         101       86          0.0                0.0
# 2107469        -0.09         101       86          0.0                0.0
# 2107470        -0.22         101       86          0.0                0.0
# 2107471        -2.98         101       86          0.0                0.0

# %% [markdown]
# Сгруппируем данные по парам покупатель - товар

# %%
df=pd.DataFrame({'user_id':users_lvl_2.user_id.values.repeat(len(users_lvl_2.candidates[0])),
                 'item_id':np.concatenate(users_lvl_2.candidates.values)})
df.head()
# Out:
#    user_id  item_id
# 0     2070  1105426
# 1     2070  1097350
# 2     2070   879194
# 3     2070   948640
# 4     2070   928263

# %% [markdown]
# Добавим два признака 'quantity', 'sales_value'

# %%
targets_lvl_2 = data_train_lvl_2[['user_id', 'item_id', 'quantity', 'sales_value']].copy()
targets_lvl_2['target'] = 1
targets_lvl_2.head()
# Out:
#          user_id  item_id  quantity  sales_value  target
# 2104867     2070  1019940         1         1.00       1
# 2107468     2021   840361         1         0.99       1
# 2107469     2021   856060         1         1.77       1
# 2107470     2021   869344         1         1.67       1
# 2107471     2021   896862         2         5.00       1

# %% [markdown]
# Соединим данные

# %%
targets_lvl_2 = df.merge(targets_lvl_2, on=['user_id', 'item_id'], how='left')
targets_lvl_2.head(10)
# Out:
#    user_id   item_id  quantity  sales_value  target
# 0     2070   1105426       NaN          NaN     NaN
# 1     2070   1097350       NaN          NaN     NaN
# 2     2070    879194       NaN          NaN     NaN
# 3     2070    948640       NaN          NaN     NaN
# 4     2070    928263       NaN          NaN     NaN
# 5     2070    944588       NaN          NaN     NaN
# 6     2070   1032703       NaN          NaN     NaN
# 7     2070  10198378       NaN          NaN     NaN
# 8     2070   1138596       NaN          NaN     NaN
# 9     2070   1092937       1.0         3.29     1.0

# %% [markdown]
# Заменим NAN на 0

# %%
targets_lvl_2['target'].fillna(0, inplace= True)
targets_lvl_2['quantity'].fillna(0, inplace= True)
targets_lvl_2['sales_value'].fillna(0, inplace= True)

targets_lvl_2.head()
# Out:
#    user_id  item_id  quantity  sales_value  target
# 0     2070  1105426       0.0          0.0     0.0
# 1     2070  1097350       0.0          0.0     0.0
# 2     2070   879194       0.0          0.0     0.0
# 3     2070   948640       0.0          0.0     0.0
# 4     2070   928263       0.0          0.0     0.0

# %% [markdown]
# Добавим признаки покупателей и признаки товаров

# %%
targets_lvl_2 = targets_lvl_2.merge(item_features, on='item_id', how='left')
targets_lvl_2 = targets_lvl_2.merge(user_features, on='user_id', how='left')

targets_lvl_2.head()
# Out:
#    user_id  item_id  quantity  sales_value  target  manufacturer department  \
# 0     2070  1105426       0.0          0.0     0.0            69       DELI
# 1     2070  1097350       0.0          0.0     0.0          2468    GROCERY
# 2     2070   879194       0.0          0.0     0.0            69    DRUG GM
# 3     2070   948640       0.0          0.0     0.0          1213    DRUG GM
# 4     2070   928263       0.0          0.0     0.0            69    DRUG GM
#
#       brand         commodity_desc   sub_commodity_desc curr_size_of_product  \
# 0   Private             SANDWICHES  SANDWICHES - (COLD)
# 1  National          DOMESTIC WINE     VALUE GLASS WINE                4 LTR
# 2   Private  DIAPERS & DISPOSABLES         BABY DIAPERS                14 CT
# 3  National  ORAL HYGIENE PRODUCTS    WHITENING SYSTEMS                 3 OZ
# 4   Private  DIAPERS & DISPOSABLES         BABY DIAPERS                13 CT
#
#   age_desc marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0    45-54                   U      50-74K        Unknown      Unknown
# 1    45-54                   U      50-74K        Unknown      Unknown
# 2    45-54                   U      50-74K        Unknown      Unknown
# 3    45-54                   U      50-74K        Unknown      Unknown
# 4    45-54                   U      50-74K        Unknown      Unknown
#
#   household_size_desc kid_category_desc
# 0                   1      None/Unknown
# 1                   1      None/Unknown
# 2                   1      None/Unknown
# 3                   1      None/Unknown
# 4                   1      None/Unknown

# %% [markdown]
# Поделим данные на X и Y

# %%
X_train = targets_lvl_2.drop('target', axis=1)
y_train = targets_lvl_2[['target']]
X_train.head()
# Out:
#    user_id  item_id  quantity  sales_value  manufacturer department     brand  \
# 0     2070  1105426       0.0          0.0            69       DELI   Private
# 1     2070  1097350       0.0          0.0          2468    GROCERY  National
# 2     2070   879194       0.0          0.0            69    DRUG GM   Private
# 3     2070   948640       0.0          0.0          1213    DRUG GM  National
# 4     2070   928263       0.0          0.0            69    DRUG GM   Private
#
#           commodity_desc   sub_commodity_desc curr_size_of_product age_desc  \
# 0             SANDWICHES  SANDWICHES - (COLD)                         45-54
# 1          DOMESTIC WINE     VALUE GLASS WINE                4 LTR    45-54
# 2  DIAPERS & DISPOSABLES         BABY DIAPERS                14 CT    45-54
# 3  ORAL HYGIENE PRODUCTS    WHITENING SYSTEMS                 3 OZ    45-54
# 4  DIAPERS & DISPOSABLES         BABY DIAPERS                13 CT    45-54
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                   U      50-74K        Unknown      Unknown
# 1                   U      50-74K        Unknown      Unknown
# 2                   U      50-74K        Unknown      Unknown
# 3                   U      50-74K        Unknown      Unknown
# 4                   U      50-74K        Unknown      Unknown
#
#   household_size_desc kid_category_desc
# 0                   1      None/Unknown
# 1                   1      None/Unknown
# 2                   1      None/Unknown
# 3                   1      None/Unknown
# 4                   1      None/Unknown

# %% [markdown]
# Создадим список категорийных признаков

# %%
cat_feats = X_train.columns[4:].tolist()
X_train[cat_feats] = X_train[cat_feats].astype('category')

cat_feats
# Out:
# ['manufacturer',
#  'department',
#  'brand',
#  'commodity_desc',
#  'sub_commodity_desc',
#  'curr_size_of_product',
#  'age_desc',
#  'marital_status_code',
#  'income_desc',
#  'homeowner_desc',
#  'hh_comp_desc',
#  'household_size_desc',
#  'kid_category_desc']

# %% [markdown]
# Для модели второго уровня выберем LGBMRanker

# %%
from lightgbm import LGBMRanker

lgb_params = { 
    'objective':'lambdarank',
    'boosting_type': 'gbdt',
    'n_estimators': 500,
    'learning_rate': 0.1,
    'max_depth': 4,
    'categorical_column': cat_feats,
    'random_state': 27,
    'verbose': 1,
    'is_unbalance': True
}

# %% [markdown]
# Создадим группы запросов

# %%
X_train['num'] = np.arange(len(X_train))
gr = X_train[['user_id', 'num']].groupby('user_id', sort=False).max()['num'].values
grs = np.concatenate((np.array([gr[0]+1]), gr[1:] - gr[:-1]))

# %% [markdown]
# Проверим правильность групп

# %%
X_train.shape
# Out:
# (111366, 18)

# %%
y_train.shape
# Out:
# (111366, 1)

# %%
np.sum(grs)
# Out:
# 111366

# %% [markdown]
# Группы созданы правильно. Натренируем модель

# %%
lgb = LGBMRanker(**lgb_params, silent=False)
lgb.fit(X_train, y_train, group=grs,
        eval_set=[(X_train, y_train)], eval_group=[grs], 
        
        eval_metric=['ndcg'],
        eval_at=[5, 10 ], early_stopping_rounds=50)
# Out:
# [1]	training's ndcg@5: 0.999742	training's ndcg@10: 0.99967
# Training until validation scores don't improve for 50 rounds
# [2]	training's ndcg@5: 0.999742	training's ndcg@10: 0.99967
# [3]	training's ndcg@5: 1	training's ndcg@10: 0.999963
# [4]	training's ndcg@5: 1	training's ndcg@10: 1
# [5]	training's ndcg@5: 1	training's ndcg@10: 1
# [6]	training's ndcg@5: 1	training's ndcg@10: 1
# [7]	training's ndcg@5: 1	training's ndcg@10: 1
# [8]	training's ndcg@5: 1	training's ndcg@10: 1
# [9]	training's ndcg@5: 1	training's ndcg@10: 1
# [10]	training's ndcg@5: 1	training's ndcg@10: 1
# [11]	training's ndcg@5: 1	training's ndcg@10: 1
# [12]	training's ndcg@5: 1	training's ndcg@10: 1
# [13]	training's ndcg@5: 1	training's ndcg@10: 1
# [14]	training's ndcg@5: 1	training's ndcg@10: 1
# [15]	training's ndcg@5: 1	training's ndcg@10: 1
# [16]	training's ndcg@5: 1	training's ndcg@10: 1
# [17]	training's ndcg@5: 1	training's ndcg@10: 1
# [18]	training's ndcg@5: 1	training's ndcg@10: 1
# [19]	training's ndcg@5: 1	training's ndcg@10: 1
# [20]	training's ndcg@5: 1	training's ndcg@10: 1
# [21]	training's ndcg@5: 1	training's ndcg@10: 1
# [22]	training's ndcg@5: 1	training's ndcg@10: 1
# [23]	training's ndcg@5: 1	training's ndcg@10: 1
# [24]	training's ndcg@5: 1	training's ndcg@10: 1
# [25]	training's ndcg@5: 1	training's ndcg@10: 1
# [26]	training's ndcg@5: 1	training's ndcg@10: 1
# [27]	training's ndcg@5: 1	training's ndcg@10: 1
# [28]	training's ndcg@5: 1	training's ndcg@10: 1
# [29]	training's ndcg@5: 1	training's ndcg@10: 1
# [30]	training's ndcg@5: 1	training's ndcg@10: 1
# [31]	training's ndcg@5: 1	training's ndcg@10: 1
# [32]	training's ndcg@5: 1	training's ndcg@10: 1
# [33]	training's ndcg@5: 1	training's ndcg@10: 1
# [34]	training's ndcg@5: 1	training's ndcg@10: 1
# [35]	training's ndcg@5: 1	training's ndcg@10: 1
# [36]	training's ndcg@5: 1	training's ndcg@10: 1
# [37]	training's ndcg@5: 1	training's ndcg@10: 1
# [38]	training's ndcg@5: 1	training's ndcg@10: 1
# [39]	training's ndcg@5: 1	training's ndcg@10: 1
# [40]	training's ndcg@5: 1	training's ndcg@10: 1
# [41]	training's ndcg@5: 1	training's ndcg@10: 1
# [42]	training's ndcg@5: 1	training's ndcg@10: 1
# [43]	training's ndcg@5: 1	training's ndcg@10: 1
# [44]	training's ndcg@5: 1	training's ndcg@10: 1
# [45]	training's ndcg@5: 1	training's ndcg@10: 1
# [46]	training's ndcg@5: 1	training's ndcg@10: 1
# [47]	training's ndcg@5: 1	training's ndcg@10: 1
# [48]	training's ndcg@5: 1	training's ndcg@10: 1
# [49]	training's ndcg@5: 1	training's ndcg@10: 1
# [50]	training's ndcg@5: 1	training's ndcg@10: 1
# [51]	training's ndcg@5: 1	training's ndcg@10: 1
# [52]	training's ndcg@5: 1	training's ndcg@10: 1
# [53]	training's ndcg@5: 1	training's ndcg@10: 1
# [54]	training's ndcg@5: 1	training's ndcg@10: 1
# [55]	training's ndcg@5: 1	training's ndcg@10: 1
# [56]	training's ndcg@5: 1	training's ndcg@10: 1
# [57]	training's ndcg@5: 1	training's ndcg@10: 1
# [58]	training's ndcg@5: 1	training's ndcg@10: 1
# [59]	training's ndcg@5: 1	training's ndcg@10: 1
# [60]	training's ndcg@5: 1	training's ndcg@10: 1
# [61]	training's ndcg@5: 1	training's ndcg@10: 1
# [62]	training's ndcg@5: 1	training's ndcg@10: 1
# [63]	training's ndcg@5: 1	training's ndcg@10: 1
# [64]	training's ndcg@5: 1	training's ndcg@10: 1
# [65]	training's ndcg@5: 1	training's ndcg@10: 1
# [66]	training's ndcg@5: 1	training's ndcg@10: 1
# [67]	training's ndcg@5: 1	training's ndcg@10: 1
# [68]	training's ndcg@5: 1	training's ndcg@10: 1
# [69]	training's ndcg@5: 1	training's ndcg@10: 1
# [70]	training's ndcg@5: 1	training's ndcg@10: 1
# [71]	training's ndcg@5: 1	training's ndcg@10: 1
# [72]	training's ndcg@5: 1	training's ndcg@10: 1
# [73]	training's ndcg@5: 1	training's ndcg@10: 1
# [74]	training's ndcg@5: 1	training's ndcg@10: 1
# [75]	training's ndcg@5: 1	training's ndcg@10: 1
# [76]	training's ndcg@5: 1	training's ndcg@10: 1
# [77]	training's ndcg@5: 1	training's ndcg@10: 1
# [78]	training's ndcg@5: 1	training's ndcg@10: 1
# [79]	training's ndcg@5: 1	training's ndcg@10: 1
# [80]	training's ndcg@5: 1	training's ndcg@10: 1
# [81]	training's ndcg@5: 1	training's ndcg@10: 1
# [82]	training's ndcg@5: 1	training's ndcg@10: 1
# [83]	training's ndcg@5: 1	training's ndcg@10: 1
# [84]	training's ndcg@5: 1	training's ndcg@10: 1
# [85]	training's ndcg@5: 1	training's ndcg@10: 1
# [86]	training's ndcg@5: 1	training's ndcg@10: 1
# [87]	training's ndcg@5: 1	training's ndcg@10: 1
# [88]	training's ndcg@5: 1	training's ndcg@10: 1
# [89]	training's ndcg@5: 1	training's ndcg@10: 1
# [90]	training's ndcg@5: 1	training's ndcg@10: 1
# [91]	training's ndcg@5: 1	training's ndcg@10: 1
# [92]	training's ndcg@5: 1	training's ndcg@10: 1
# [93]	training's ndcg@5: 1	training's ndcg@10: 1
# [94]	training's ndcg@5: 1	training's ndcg@10: 1
# [95]	training's ndcg@5: 1	training's ndcg@10: 1
# [96]	training's ndcg@5: 1	training's ndcg@10: 1
# [97]	training's ndcg@5: 1	training's ndcg@10: 1
# [98]	training's ndcg@5: 1	training's ndcg@10: 1
# [99]	training's ndcg@5: 1	training's ndcg@10: 1
# [100]	training's ndcg@5: 1	training's ndcg@10: 1
# [101]	training's ndcg@5: 1	training's ndcg@10: 1
# [102]	training's ndcg@5: 1	training's ndcg@10: 1
# [103]	training's ndcg@5: 1	training's ndcg@10: 1
# [104]	training's ndcg@5: 1	training's ndcg@10: 1
# [105]	training's ndcg@5: 1	training's ndcg@10: 1
# [106]	training's ndcg@5: 1	training's ndcg@10: 1
# [107]	training's ndcg@5: 1	training's ndcg@10: 1
# [108]	training's ndcg@5: 1	training's ndcg@10: 1
# [109]	training's ndcg@5: 1	training's ndcg@10: 1
# [110]	training's ndcg@5: 1	training's ndcg@10: 1
# [111]	training's ndcg@5: 1	training's ndcg@10: 1
# [112]	training's ndcg@5: 1	training's ndcg@10: 1
# [113]	training's ndcg@5: 1	training's ndcg@10: 1
# [114]	training's ndcg@5: 1	training's ndcg@10: 1
# [115]	training's ndcg@5: 1	training's ndcg@10: 1
# [116]	training's ndcg@5: 1	training's ndcg@10: 1
# [117]	training's ndcg@5: 1	training's ndcg@10: 1
# [118]	training's ndcg@5: 1	training's ndcg@10: 1
# [119]	training's ndcg@5: 1	training's ndcg@10: 1
# [120]	training's ndcg@5: 1	training's ndcg@10: 1
# [121]	training's ndcg@5: 1	training's ndcg@10: 1
# [122]	training's ndcg@5: 1	training's ndcg@10: 1
# [123]	training's ndcg@5: 1	training's ndcg@10: 1
# [124]	training's ndcg@5: 1	training's ndcg@10: 1
# [125]	training's ndcg@5: 1	training's ndcg@10: 1
# [126]	training's ndcg@5: 1	training's ndcg@10: 1
# [127]	training's ndcg@5: 1	training's ndcg@10: 1
# [128]	training's ndcg@5: 1	training's ndcg@10: 1
# [129]	training's ndcg@5: 1	training's ndcg@10: 1
# [130]	training's ndcg@5: 1	training's ndcg@10: 1
# [131]	training's ndcg@5: 1	training's ndcg@10: 1
# [132]	training's ndcg@5: 1	training's ndcg@10: 1
# [133]	training's ndcg@5: 1	training's ndcg@10: 1
# [134]	training's ndcg@5: 1	training's ndcg@10: 1
# [135]	training's ndcg@5: 1	training's ndcg@10: 1
# [136]	training's ndcg@5: 1	training's ndcg@10: 1
# [137]	training's ndcg@5: 1	training's ndcg@10: 1
# [138]	training's ndcg@5: 1	training's ndcg@10: 1
# [139]	training's ndcg@5: 1	training's ndcg@10: 1
# [140]	training's ndcg@5: 1	training's ndcg@10: 1
# [141]	training's ndcg@5: 1	training's ndcg@10: 1
# [142]	training's ndcg@5: 1	training's ndcg@10: 1
# [143]	training's ndcg@5: 1	training's ndcg@10: 1
# [144]	training's ndcg@5: 1	training's ndcg@10: 1
# [145]	training's ndcg@5: 1	training's ndcg@10: 1
# [146]	training's ndcg@5: 1	training's ndcg@10: 1
# [147]	training's ndcg@5: 1	training's ndcg@10: 1
# [148]	training's ndcg@5: 1	training's ndcg@10: 1
# [149]	training's ndcg@5: 1	training's ndcg@10: 1
# [150]	training's ndcg@5: 1	training's ndcg@10: 1
# [151]	training's ndcg@5: 1	training's ndcg@10: 1
# [152]	training's ndcg@5: 1	training's ndcg@10: 1
# [153]	training's ndcg@5: 1	training's ndcg@10: 1
# [154]	training's ndcg@5: 1	training's ndcg@10: 1
# [155]	training's ndcg@5: 1	training's ndcg@10: 1
# [156]	training's ndcg@5: 1	training's ndcg@10: 1
# [157]	training's ndcg@5: 1	training's ndcg@10: 1
# [158]	training's ndcg@5: 1	training's ndcg@10: 1
# [159]	training's ndcg@5: 1	training's ndcg@10: 1
# [160]	training's ndcg@5: 1	training's ndcg@10: 1
# [161]	training's ndcg@5: 1	training's ndcg@10: 1
# [162]	training's ndcg@5: 1	training's ndcg@10: 1
# [163]	training's ndcg@5: 1	training's ndcg@10: 1
# [164]	training's ndcg@5: 1	training's ndcg@10: 1
# [165]	training's ndcg@5: 1	training's ndcg@10: 1
# [166]	training's ndcg@5: 1	training's ndcg@10: 1
# [167]	training's ndcg@5: 1	training's ndcg@10: 1
# [168]	training's ndcg@5: 1	training's ndcg@10: 1
# [169]	training's ndcg@5: 1	training's ndcg@10: 1
# [170]	training's ndcg@5: 1	training's ndcg@10: 1
# [171]	training's ndcg@5: 1	training's ndcg@10: 1
# [172]	training's ndcg@5: 1	training's ndcg@10: 1
# [173]	training's ndcg@5: 1	training's ndcg@10: 1
# [174]	training's ndcg@5: 1	training's ndcg@10: 1
# [175]	training's ndcg@5: 1	training's ndcg@10: 1
# [176]	training's ndcg@5: 1	training's ndcg@10: 1
# [177]	training's ndcg@5: 1	training's ndcg@10: 1
# [178]	training's ndcg@5: 1	training's ndcg@10: 1
# [179]	training's ndcg@5: 1	training's ndcg@10: 1
# [180]	training's ndcg@5: 1	training's ndcg@10: 1
# [181]	training's ndcg@5: 1	training's ndcg@10: 1
# [182]	training's ndcg@5: 1	training's ndcg@10: 1
# [183]	training's ndcg@5: 1	training's ndcg@10: 1
# [184]	training's ndcg@5: 1	training's ndcg@10: 1
# [185]	training's ndcg@5: 1	training's ndcg@10: 1
# [186]	training's ndcg@5: 1	training's ndcg@10: 1
# [187]	training's ndcg@5: 1	training's ndcg@10: 1
# [188]	training's ndcg@5: 1	training's ndcg@10: 1
# [189]	training's ndcg@5: 1	training's ndcg@10: 1
# [190]	training's ndcg@5: 1	training's ndcg@10: 1
# [191]	training's ndcg@5: 1	training's ndcg@10: 1
# [192]	training's ndcg@5: 1	training's ndcg@10: 1
# [193]	training's ndcg@5: 1	training's ndcg@10: 1
# [194]	training's ndcg@5: 1	training's ndcg@10: 1
# [195]	training's ndcg@5: 1	training's ndcg@10: 1
# [196]	training's ndcg@5: 1	training's ndcg@10: 1
# [197]	training's ndcg@5: 1	training's ndcg@10: 1
# [198]	training's ndcg@5: 1	training's ndcg@10: 1
# [199]	training's ndcg@5: 1	training's ndcg@10: 1
# [200]	training's ndcg@5: 1	training's ndcg@10: 1
# [201]	training's ndcg@5: 1	training's ndcg@10: 1
# [202]	training's ndcg@5: 1	training's ndcg@10: 1
# [203]	training's ndcg@5: 1	training's ndcg@10: 1
# [204]	training's ndcg@5: 1	training's ndcg@10: 1
# [205]	training's ndcg@5: 1	training's ndcg@10: 1
# [206]	training's ndcg@5: 1	training's ndcg@10: 1
# [207]	training's ndcg@5: 1	training's ndcg@10: 1
# [208]	training's ndcg@5: 1	training's ndcg@10: 1
# [209]	training's ndcg@5: 1	training's ndcg@10: 1
# [210]	training's ndcg@5: 1	training's ndcg@10: 1
# [211]	training's ndcg@5: 1	training's ndcg@10: 1
# [212]	training's ndcg@5: 1	training's ndcg@10: 1
# [213]	training's ndcg@5: 1	training's ndcg@10: 1
# [214]	training's ndcg@5: 1	training's ndcg@10: 1
# [215]	training's ndcg@5: 1	training's ndcg@10: 1
# [216]	training's ndcg@5: 1	training's ndcg@10: 1
# [217]	training's ndcg@5: 1	training's ndcg@10: 1
# [218]	training's ndcg@5: 1	training's ndcg@10: 1
# [219]	training's ndcg@5: 1	training's ndcg@10: 1
# [220]	training's ndcg@5: 1	training's ndcg@10: 1
# [221]	training's ndcg@5: 1	training's ndcg@10: 1
# [222]	training's ndcg@5: 1	training's ndcg@10: 1
# [223]	training's ndcg@5: 1	training's ndcg@10: 1
# [224]	training's ndcg@5: 1	training's ndcg@10: 1
# [225]	training's ndcg@5: 1	training's ndcg@10: 1
# [226]	training's ndcg@5: 1	training's ndcg@10: 1
# [227]	training's ndcg@5: 1	training's ndcg@10: 1
# [228]	training's ndcg@5: 1	training's ndcg@10: 1
# [229]	training's ndcg@5: 1	training's ndcg@10: 1
# [230]	training's ndcg@5: 1	training's ndcg@10: 1
# [231]	training's ndcg@5: 1	training's ndcg@10: 1
# [232]	training's ndcg@5: 1	training's ndcg@10: 1
# [233]	training's ndcg@5: 1	training's ndcg@10: 1
# [234]	training's ndcg@5: 1	training's ndcg@10: 1
# [235]	training's ndcg@5: 1	training's ndcg@10: 1
# [236]	training's ndcg@5: 1	training's ndcg@10: 1
# [237]	training's ndcg@5: 1	training's ndcg@10: 1
# [238]	training's ndcg@5: 1	training's ndcg@10: 1
# [239]	training's ndcg@5: 1	training's ndcg@10: 1
# [240]	training's ndcg@5: 1	training's ndcg@10: 1
# [241]	training's ndcg@5: 1	training's ndcg@10: 1
# [242]	training's ndcg@5: 1	training's ndcg@10: 1
# [243]	training's ndcg@5: 1	training's ndcg@10: 1
# [244]	training's ndcg@5: 1	training's ndcg@10: 1
# [245]	training's ndcg@5: 1	training's ndcg@10: 1
# [246]	training's ndcg@5: 1	training's ndcg@10: 1
# [247]	training's ndcg@5: 1	training's ndcg@10: 1
# [248]	training's ndcg@5: 1	training's ndcg@10: 1
# [249]	training's ndcg@5: 1	training's ndcg@10: 1
# [250]	training's ndcg@5: 1	training's ndcg@10: 1
# [251]	training's ndcg@5: 1	training's ndcg@10: 1
# [252]	training's ndcg@5: 1	training's ndcg@10: 1
# [253]	training's ndcg@5: 1	training's ndcg@10: 1
# [254]	training's ndcg@5: 1	training's ndcg@10: 1
# [255]	training's ndcg@5: 1	training's ndcg@10: 1
# [256]	training's ndcg@5: 1	training's ndcg@10: 1
# [257]	training's ndcg@5: 1	training's ndcg@10: 1
# [258]	training's ndcg@5: 1	training's ndcg@10: 1
# [259]	training's ndcg@5: 1	training's ndcg@10: 1
# [260]	training's ndcg@5: 1	training's ndcg@10: 1
# [261]	training's ndcg@5: 1	training's ndcg@10: 1
# [262]	training's ndcg@5: 1	training's ndcg@10: 1
# [263]	training's ndcg@5: 1	training's ndcg@10: 1
# [264]	training's ndcg@5: 1	training's ndcg@10: 1
# [265]	training's ndcg@5: 1	training's ndcg@10: 1
# [266]	training's ndcg@5: 1	training's ndcg@10: 1
# [267]	training's ndcg@5: 1	training's ndcg@10: 1
# [268]	training's ndcg@5: 1	training's ndcg@10: 1
# [269]	training's ndcg@5: 1	training's ndcg@10: 1
# [270]	training's ndcg@5: 1	training's ndcg@10: 1
# [271]	training's ndcg@5: 1	training's ndcg@10: 1
# [272]	training's ndcg@5: 1	training's ndcg@10: 1
# [273]	training's ndcg@5: 1	training's ndcg@10: 1
# [274]	training's ndcg@5: 1	training's ndcg@10: 1
# [275]	training's ndcg@5: 1	training's ndcg@10: 1
# [276]	training's ndcg@5: 1	training's ndcg@10: 1
# [277]	training's ndcg@5: 1	training's ndcg@10: 1
# [278]	training's ndcg@5: 1	training's ndcg@10: 1
# [279]	training's ndcg@5: 1	training's ndcg@10: 1
# [280]	training's ndcg@5: 1	training's ndcg@10: 1
# [281]	training's ndcg@5: 1	training's ndcg@10: 1
# [282]	training's ndcg@5: 1	training's ndcg@10: 1
# [283]	training's ndcg@5: 1	training's ndcg@10: 1
# [284]	training's ndcg@5: 1	training's ndcg@10: 1
# [285]	training's ndcg@5: 1	training's ndcg@10: 1
# [286]	training's ndcg@5: 1	training's ndcg@10: 1
# [287]	training's ndcg@5: 1	training's ndcg@10: 1
# [288]	training's ndcg@5: 1	training's ndcg@10: 1
# [289]	training's ndcg@5: 1	training's ndcg@10: 1
# [290]	training's ndcg@5: 1	training's ndcg@10: 1
# [291]	training's ndcg@5: 1	training's ndcg@10: 1
# [292]	training's ndcg@5: 1	training's ndcg@10: 1
# [293]	training's ndcg@5: 1	training's ndcg@10: 1
# [294]	training's ndcg@5: 1	training's ndcg@10: 1
# [295]	training's ndcg@5: 1	training's ndcg@10: 1
# [296]	training's ndcg@5: 1	training's ndcg@10: 1
# [297]	training's ndcg@5: 1	training's ndcg@10: 1
# [298]	training's ndcg@5: 1	training's ndcg@10: 1
# [299]	training's ndcg@5: 1	training's ndcg@10: 1
# [300]	training's ndcg@5: 1	training's ndcg@10: 1
# [301]	training's ndcg@5: 1	training's ndcg@10: 1
# [302]	training's ndcg@5: 1	training's ndcg@10: 1
# [303]	training's ndcg@5: 1	training's ndcg@10: 1
# [304]	training's ndcg@5: 1	training's ndcg@10: 1
# [305]	training's ndcg@5: 1	training's ndcg@10: 1
# [306]	training's ndcg@5: 1	training's ndcg@10: 1
# [307]	training's ndcg@5: 1	training's ndcg@10: 1
# [308]	training's ndcg@5: 1	training's ndcg@10: 1
# [309]	training's ndcg@5: 1	training's ndcg@10: 1
# [310]	training's ndcg@5: 1	training's ndcg@10: 1
# [311]	training's ndcg@5: 1	training's ndcg@10: 1
# [312]	training's ndcg@5: 1	training's ndcg@10: 1
# [313]	training's ndcg@5: 1	training's ndcg@10: 1
# [314]	training's ndcg@5: 1	training's ndcg@10: 1
# [315]	training's ndcg@5: 1	training's ndcg@10: 1
# [316]	training's ndcg@5: 1	training's ndcg@10: 1
# [317]	training's ndcg@5: 1	training's ndcg@10: 1
# [318]	training's ndcg@5: 1	training's ndcg@10: 1
# [319]	training's ndcg@5: 1	training's ndcg@10: 1
# [320]	training's ndcg@5: 1	training's ndcg@10: 1
# [321]	training's ndcg@5: 1	training's ndcg@10: 1
# [322]	training's ndcg@5: 1	training's ndcg@10: 1
# [323]	training's ndcg@5: 1	training's ndcg@10: 1
# [324]	training's ndcg@5: 1	training's ndcg@10: 1
# [325]	training's ndcg@5: 1	training's ndcg@10: 1
# [326]	training's ndcg@5: 1	training's ndcg@10: 1
# [327]	training's ndcg@5: 1	training's ndcg@10: 1
# [328]	training's ndcg@5: 1	training's ndcg@10: 1
# [329]	training's ndcg@5: 1	training's ndcg@10: 1
# [330]	training's ndcg@5: 1	training's ndcg@10: 1
# [331]	training's ndcg@5: 1	training's ndcg@10: 1
# [332]	training's ndcg@5: 1	training's ndcg@10: 1
# [333]	training's ndcg@5: 1	training's ndcg@10: 1
# [334]	training's ndcg@5: 1	training's ndcg@10: 1
# [335]	training's ndcg@5: 1	training's ndcg@10: 1
# [336]	training's ndcg@5: 1	training's ndcg@10: 1
# [337]	training's ndcg@5: 1	training's ndcg@10: 1
# [338]	training's ndcg@5: 1	training's ndcg@10: 1
# [339]	training's ndcg@5: 1	training's ndcg@10: 1
# [340]	training's ndcg@5: 1	training's ndcg@10: 1
# [341]	training's ndcg@5: 1	training's ndcg@10: 1
# [342]	training's ndcg@5: 1	training's ndcg@10: 1
# [343]	training's ndcg@5: 1	training's ndcg@10: 1
# [344]	training's ndcg@5: 1	training's ndcg@10: 1
# [345]	training's ndcg@5: 1	training's ndcg@10: 1
# [346]	training's ndcg@5: 1	training's ndcg@10: 1
# [347]	training's ndcg@5: 1	training's ndcg@10: 1
# [348]	training's ndcg@5: 1	training's ndcg@10: 1
# [349]	training's ndcg@5: 1	training's ndcg@10: 1
# [350]	training's ndcg@5: 1	training's ndcg@10: 1
# [351]	training's ndcg@5: 1	training's ndcg@10: 1
# [352]	training's ndcg@5: 1	training's ndcg@10: 1
# [353]	training's ndcg@5: 1	training's ndcg@10: 1
# [354]	training's ndcg@5: 1	training's ndcg@10: 1
# [355]	training's ndcg@5: 1	training's ndcg@10: 1
# [356]	training's ndcg@5: 1	training's ndcg@10: 1
# [357]	training's ndcg@5: 1	training's ndcg@10: 1
# [358]	training's ndcg@5: 1	training's ndcg@10: 1
# [359]	training's ndcg@5: 1	training's ndcg@10: 1
# [360]	training's ndcg@5: 1	training's ndcg@10: 1
# [361]	training's ndcg@5: 1	training's ndcg@10: 1
# [362]	training's ndcg@5: 1	training's ndcg@10: 1
# [363]	training's ndcg@5: 1	training's ndcg@10: 1
# [364]	training's ndcg@5: 1	training's ndcg@10: 1
# [365]	training's ndcg@5: 1	training's ndcg@10: 1
# [366]	training's ndcg@5: 1	training's ndcg@10: 1
# [367]	training's ndcg@5: 1	training's ndcg@10: 1
# [368]	training's ndcg@5: 1	training's ndcg@10: 1
# [369]	training's ndcg@5: 1	training's ndcg@10: 1
# [370]	training's ndcg@5: 1	training's ndcg@10: 1
# [371]	training's ndcg@5: 1	training's ndcg@10: 1
# [372]	training's ndcg@5: 1	training's ndcg@10: 1
# [373]	training's ndcg@5: 1	training's ndcg@10: 1
# [374]	training's ndcg@5: 1	training's ndcg@10: 1
# [375]	training's ndcg@5: 1	training's ndcg@10: 1
# [376]	training's ndcg@5: 1	training's ndcg@10: 1
# [377]	training's ndcg@5: 1	training's ndcg@10: 1
# [378]	training's ndcg@5: 1	training's ndcg@10: 1
# [379]	training's ndcg@5: 1	training's ndcg@10: 1
# [380]	training's ndcg@5: 1	training's ndcg@10: 1
# [381]	training's ndcg@5: 1	training's ndcg@10: 1
# [382]	training's ndcg@5: 1	training's ndcg@10: 1
# [383]	training's ndcg@5: 1	training's ndcg@10: 1
# [384]	training's ndcg@5: 1	training's ndcg@10: 1
# [385]	training's ndcg@5: 1	training's ndcg@10: 1
# [386]	training's ndcg@5: 1	training's ndcg@10: 1
# [387]	training's ndcg@5: 1	training's ndcg@10: 1
# [388]	training's ndcg@5: 1	training's ndcg@10: 1
# [389]	training's ndcg@5: 1	training's ndcg@10: 1
# [390]	training's ndcg@5: 1	training's ndcg@10: 1
# [391]	training's ndcg@5: 1	training's ndcg@10: 1
# [392]	training's ndcg@5: 1	training's ndcg@10: 1
# [393]	training's ndcg@5: 1	training's ndcg@10: 1
# [394]	training's ndcg@5: 1	training's ndcg@10: 1
# [395]	training's ndcg@5: 1	training's ndcg@10: 1
# [396]	training's ndcg@5: 1	training's ndcg@10: 1
# [397]	training's ndcg@5: 1	training's ndcg@10: 1
# [398]	training's ndcg@5: 1	training's ndcg@10: 1
# [399]	training's ndcg@5: 1	training's ndcg@10: 1
# [400]	training's ndcg@5: 1	training's ndcg@10: 1
# [401]	training's ndcg@5: 1	training's ndcg@10: 1
# [402]	training's ndcg@5: 1	training's ndcg@10: 1
# [403]	training's ndcg@5: 1	training's ndcg@10: 1
# [404]	training's ndcg@5: 1	training's ndcg@10: 1
# [405]	training's ndcg@5: 1	training's ndcg@10: 1
# [406]	training's ndcg@5: 1	training's ndcg@10: 1
# [407]	training's ndcg@5: 1	training's ndcg@10: 1
# [408]	training's ndcg@5: 1	training's ndcg@10: 1
# [409]	training's ndcg@5: 1	training's ndcg@10: 1
# [410]	training's ndcg@5: 1	training's ndcg@10: 1
# [411]	training's ndcg@5: 1	training's ndcg@10: 1
# [412]	training's ndcg@5: 1	training's ndcg@10: 1
# [413]	training's ndcg@5: 1	training's ndcg@10: 1
# [414]	training's ndcg@5: 1	training's ndcg@10: 1
# [415]	training's ndcg@5: 1	training's ndcg@10: 1
# [416]	training's ndcg@5: 1	training's ndcg@10: 1
# [417]	training's ndcg@5: 1	training's ndcg@10: 1
# [418]	training's ndcg@5: 1	training's ndcg@10: 1
# [419]	training's ndcg@5: 1	training's ndcg@10: 1
# [420]	training's ndcg@5: 1	training's ndcg@10: 1
# [421]	training's ndcg@5: 1	training's ndcg@10: 1
# [422]	training's ndcg@5: 1	training's ndcg@10: 1
# [423]	training's ndcg@5: 1	training's ndcg@10: 1
# [424]	training's ndcg@5: 1	training's ndcg@10: 1
# [425]	training's ndcg@5: 1	training's ndcg@10: 1
# [426]	training's ndcg@5: 1	training's ndcg@10: 1
# [427]	training's ndcg@5: 1	training's ndcg@10: 1
# [428]	training's ndcg@5: 1	training's ndcg@10: 1
# [429]	training's ndcg@5: 1	training's ndcg@10: 1
# [430]	training's ndcg@5: 1	training's ndcg@10: 1
# [431]	training's ndcg@5: 1	training's ndcg@10: 1
# [432]	training's ndcg@5: 1	training's ndcg@10: 1
# [433]	training's ndcg@5: 1	training's ndcg@10: 1
# [434]	training's ndcg@5: 1	training's ndcg@10: 1
# [435]	training's ndcg@5: 1	training's ndcg@10: 1
# [436]	training's ndcg@5: 1	training's ndcg@10: 1
# [437]	training's ndcg@5: 1	training's ndcg@10: 1
# [438]	training's ndcg@5: 1	training's ndcg@10: 1
# [439]	training's ndcg@5: 1	training's ndcg@10: 1
# [440]	training's ndcg@5: 1	training's ndcg@10: 1
# [441]	training's ndcg@5: 1	training's ndcg@10: 1
# [442]	training's ndcg@5: 1	training's ndcg@10: 1
# [443]	training's ndcg@5: 1	training's ndcg@10: 1
# [444]	training's ndcg@5: 1	training's ndcg@10: 1
# [445]	training's ndcg@5: 1	training's ndcg@10: 1
# [446]	training's ndcg@5: 1	training's ndcg@10: 1
# [447]	training's ndcg@5: 1	training's ndcg@10: 1
# [448]	training's ndcg@5: 1	training's ndcg@10: 1
# [449]	training's ndcg@5: 1	training's ndcg@10: 1
# [450]	training's ndcg@5: 1	training's ndcg@10: 1
# [451]	training's ndcg@5: 1	training's ndcg@10: 1
# [452]	training's ndcg@5: 1	training's ndcg@10: 1
# [453]	training's ndcg@5: 1	training's ndcg@10: 1
# [454]	training's ndcg@5: 1	training's ndcg@10: 1
# [455]	training's ndcg@5: 1	training's ndcg@10: 1
# [456]	training's ndcg@5: 1	training's ndcg@10: 1
# [457]	training's ndcg@5: 1	training's ndcg@10: 1
# [458]	training's ndcg@5: 1	training's ndcg@10: 1
# [459]	training's ndcg@5: 1	training's ndcg@10: 1
# [460]	training's ndcg@5: 1	training's ndcg@10: 1
# [461]	training's ndcg@5: 1	training's ndcg@10: 1
# [462]	training's ndcg@5: 1	training's ndcg@10: 1
# [463]	training's ndcg@5: 1	training's ndcg@10: 1
# [464]	training's ndcg@5: 1	training's ndcg@10: 1
# [465]	training's ndcg@5: 1	training's ndcg@10: 1
# [466]	training's ndcg@5: 1	training's ndcg@10: 1
# [467]	training's ndcg@5: 1	training's ndcg@10: 1
# [468]	training's ndcg@5: 1	training's ndcg@10: 1
# [469]	training's ndcg@5: 1	training's ndcg@10: 1
# [470]	training's ndcg@5: 1	training's ndcg@10: 1
# [471]	training's ndcg@5: 1	training's ndcg@10: 1
# [472]	training's ndcg@5: 1	training's ndcg@10: 1
# [473]	training's ndcg@5: 1	training's ndcg@10: 1
# [474]	training's ndcg@5: 1	training's ndcg@10: 1
# [475]	training's ndcg@5: 1	training's ndcg@10: 1
# [476]	training's ndcg@5: 1	training's ndcg@10: 1
# [477]	training's ndcg@5: 1	training's ndcg@10: 1
# [478]	training's ndcg@5: 1	training's ndcg@10: 1
# [479]	training's ndcg@5: 1	training's ndcg@10: 1
# [480]	training's ndcg@5: 1	training's ndcg@10: 1
# [481]	training's ndcg@5: 1	training's ndcg@10: 1
# [482]	training's ndcg@5: 1	training's ndcg@10: 1
# [483]	training's ndcg@5: 1	training's ndcg@10: 1
# [484]	training's ndcg@5: 1	training's ndcg@10: 1
# [485]	training's ndcg@5: 1	training's ndcg@10: 1
# [486]	training's ndcg@5: 1	training's ndcg@10: 1
# [487]	training's ndcg@5: 1	training's ndcg@10: 1
# [488]	training's ndcg@5: 1	training's ndcg@10: 1
# [489]	training's ndcg@5: 1	training's ndcg@10: 1
# [490]	training's ndcg@5: 1	training's ndcg@10: 1
# [491]	training's ndcg@5: 1	training's ndcg@10: 1
# [492]	training's ndcg@5: 1	training's ndcg@10: 1
# [493]	training's ndcg@5: 1	training's ndcg@10: 1
# [494]	training's ndcg@5: 1	training's ndcg@10: 1
# [495]	training's ndcg@5: 1	training's ndcg@10: 1
# [496]	training's ndcg@5: 1	training's ndcg@10: 1
# [497]	training's ndcg@5: 1	training's ndcg@10: 1
# [498]	training's ndcg@5: 1	training's ndcg@10: 1
# [499]	training's ndcg@5: 1	training's ndcg@10: 1
# [500]	training's ndcg@5: 1	training's ndcg@10: 1
# Did not meet early stopping. Best iteration is:
# [3]	training's ndcg@5: 1	training's ndcg@10: 0.999963
# LGBMRanker(boosting_type='gbdt',
#            categorical_column=['manufacturer', 'department', 'brand',
#                                'commodity_desc', 'sub_commodity_desc',
#                                'curr_size_of_product', 'age_desc',
#                                'marital_status_code', 'income_desc',
#                                'homeowner_desc', 'hh_comp_desc',
#                                'household_size_desc', 'kid_category_desc'],
#            class_weight=None, colsample_bytree=1.0, importance_type='split',
#            is_unbalance=True, learning_rate=0.1, max_depth=4,
#            min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#            n_estimators=500, n_jobs=-1, num_leaves=31, objective='lambdarank',
#            random_state=27, reg_alpha=0.0, reg_lambda=0.0, silent=False,
#            subsample=1.0, subsample_for_bin=200000, subsample_freq=0,
#            verbose=1)

# %% [markdown]
# Сделаем предсказания на тренировочных данных

# %%
train_preds = lgb.predict(X_train)

# %%
train_preds
# Out:
# array([-0.50526121, -0.50526121, -0.50526121, ..., -0.51443757,
#        -0.51443757, -0.51443757])

# %%
X_train["predicted_ranking"] = train_preds
X_train.sort_values("predicted_ranking", ascending=False)
X_train.head()
# Out:
#    user_id  item_id  quantity  sales_value manufacturer department     brand  \
# 0     2070  1105426       0.0          0.0           69       DELI   Private
# 1     2070  1097350       0.0          0.0         2468    GROCERY  National
# 2     2070   879194       0.0          0.0           69    DRUG GM   Private
# 3     2070   948640       0.0          0.0         1213    DRUG GM  National
# 4     2070   928263       0.0          0.0           69    DRUG GM   Private
#
#           commodity_desc   sub_commodity_desc curr_size_of_product age_desc  \
# 0             SANDWICHES  SANDWICHES - (COLD)                         45-54
# 1          DOMESTIC WINE     VALUE GLASS WINE                4 LTR    45-54
# 2  DIAPERS & DISPOSABLES         BABY DIAPERS                14 CT    45-54
# 3  ORAL HYGIENE PRODUCTS    WHITENING SYSTEMS                 3 OZ    45-54
# 4  DIAPERS & DISPOSABLES         BABY DIAPERS                13 CT    45-54
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                   U      50-74K        Unknown      Unknown
# 1                   U      50-74K        Unknown      Unknown
# 2                   U      50-74K        Unknown      Unknown
# 3                   U      50-74K        Unknown      Unknown
# 4                   U      50-74K        Unknown      Unknown
#
#   household_size_desc kid_category_desc  num  predicted_ranking
# 0                   1      None/Unknown    0          -0.505261
# 1                   1      None/Unknown    1          -0.505261
# 2                   1      None/Unknown    2          -0.505261
# 3                   1      None/Unknown    3          -0.505261
# 4                   1      None/Unknown    4          -0.505261

# %%
result_gbm = X_train.groupby('user_id')['item_id'].unique().reset_index()
result_gbm.columns = ['user_id', 'predicted_ranking']
result_gbm.head()
# Out:
#    user_id                                  predicted_ranking
# 0        1  [856942, 9297615, 5577022, 877391, 9655212, 88...
# 1        2  [911974, 1076580, 1103898, 5567582, 1056620, 9...
# 2        4  [6391541, 1052294, 891423, 936470, 1137010, 11...
# 3        6  [13003092, 972416, 995598, 923600, 1138596, 10...
# 4        7  [998519, 894360, 7147142, 9338009, 896666, 939...

# %% [markdown]
# Валидационные данные

# %%
data_val_lvl_2.head()
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2277416      338  41260573635  636   840173         1         1.99       369
# 2277417      338  41260573635  636  1037348         1         0.89       369
# 2277418      338  41260573635  636  5592737         2         1.58       369
# 2277419      338  41260573635  636  7441679         1         3.69       369
# 2277420      338  41260573635  636  7442317         1         2.69       369
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2277416          0.0         112       92          0.0                0.0
# 2277417         -0.3         112       92          0.0                0.0
# 2277418         -0.2         112       92          0.0                0.0
# 2277419          0.0         112       92          0.0                0.0
# 2277420          0.0         112       92          0.0                0.0

# %% [markdown]
# Сгруппируем данные

# %%
result_lvl_2 = data_val_lvl_2.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_2.columns = ['user_id', 'actual']
result_lvl_2.head()
# Out:
#    user_id                                             actual
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...
# 2        6  [920308, 926804, 946489, 1006718, 1017061, 107...
# 3        7  [840386, 889774, 898068, 909714, 929067, 95347...
# 4        8  [835098, 872137, 910439, 924610, 992977, 10412...

# %%
result_lvl_2['predicted_ranking'] = result_gbm['predicted_ranking']
result_lvl_2['precision'] = precision_at_k(list(result_gbm['predicted_ranking'])[0], list(result_lvl_2['actual'])[0], 5)
result_lvl_2.head()
# Out:
#    user_id                                             actual  \
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...
# 2        6  [920308, 926804, 946489, 1006718, 1017061, 107...
# 3        7  [840386, 889774, 898068, 909714, 929067, 95347...
# 4        8  [835098, 872137, 910439, 924610, 992977, 10412...
#
#                                    predicted_ranking  precision
# 0  [856942, 9297615, 5577022, 877391, 9655212, 88...        0.6
# 1  [911974, 1076580, 1103898, 5567582, 1056620, 9...        0.6
# 2  [6391541, 1052294, 891423, 936470, 1137010, 11...        0.6
# 3  [13003092, 972416, 995598, 923600, 1138596, 10...        0.6
# 4  [998519, 894360, 7147142, 9338009, 896666, 939...        0.6

# %%
result_lvl_2.max()
# Out:
# user_id      2500.0
# precision       0.6
# dtype: float64

# %% [markdown]
# precision@5 составлят 0.6

# %%
result_lvl_2.to_csv('out.csv') recommendations.csv
